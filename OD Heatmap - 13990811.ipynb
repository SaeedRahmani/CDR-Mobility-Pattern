# %%
"""
inputs = Weekday and weekend matrices({weekday : [PA(HBO,HBW,NHB) , OD(HBO,HBW,NHB)], weekend :[PA(HBO,HBW,NHB) , OD(HBO,HBW,NHB)]})(16 matrices)
outputs = Matrices Heatmaps(which shows movements patterns)

index zero means outsides of Tehran! it was not possible to divide outsides of tehran duo to our Great Shapefiles!!!



"""

# %% [markdown]
# # import libraries

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Total OD

# %%
data = pd.read_excel('C:Desktop/Sample Matrix.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(data,cmap='magma',linewidths=0.2)
plt.title('OD Total Matrix  WeekDay')
# Out:
# Text(0.5, 1, 'OD Total Matrix  WeekDay')

# %% [markdown]
# # HBW OD

# %%
ODHBW = pd.read_excel('C:Desktop/HBW OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(ODHBW,cmap='magma',linewidths=0.2)
plt.title('OD HBW Matrix WeekDay')
# Out:
# Text(0.5, 1, 'OD HBW Matrix WeekDay')

# %% [markdown]
# # HBO OD

# %%
ODHBO = pd.read_excel('C:Desktop/HBO OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(ODHBO,cmap='magma',linewidths=0.2)
plt.title('OD HBO Matrix WeekDay')
# Out:
# Text(0.5, 1, 'OD HBO Matrix WeekDay')

# %% [markdown]
# # NHB OD

# %%
ODNHB = pd.read_excel('C:Desktop/NHB OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(ODNHB,cmap='magma',linewidths=0.2)
plt.title('OD NHB Matrix WeekDay ')
# Out:
# Text(0.5, 1, 'OD NHB Matrix WeekDay ')

# %% [markdown]
# # NHB PA Matrice

# %%
PANHB = pd.read_excel('C:Desktop/PA NHB OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(PANHB,cmap='magma',linewidths=0.2)
plt.title('PA Non-Home-Based(NHB) Matrix')
# Out:
# Text(0.5, 1, 'PA Non-Home-Based(NHB) Matrix')

# %% [markdown]
# # HBO PA Matrice

# %%
PAHBO = pd.read_excel('C:Desktop/PA HBO OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(PAHBO,cmap='magma',linewidths=0.2)
plt.title('PA Home-Based-Other(HBO) Matrix')
# Out:
# Text(0.5, 1, 'PA Home-Based-Other(HBO) Matrix')

# %% [markdown]
# # HBW PA Matrice

# %%
PAHBW = pd.read_excel('C:Desktop/PA HBW OD.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(PAHBW,cmap='magma',linewidths=0.2)
plt.title('PA Home-Based-Work(HBW) Matrix')
# Out:
# Text(0.5, 1, 'PA Home-Based-Work(HBW) Matrix')

# %% [markdown]
# # PA Total Matrice

# %%
PATot = pd.read_excel('C:Desktop/PA.xlsx')

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax=sns.heatmap(PATot,cmap='magma',linewidths=0.2)
plt.title('PA All Purposes Matrix')
# Out:
# Text(0.5, 1, 'PA All Purposes Matrix')
